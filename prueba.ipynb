// %%
import $ivy.`org.apache.spark::spark-sql:4.1.1`

import org.apache.spark.sql.SparkSession
// Out:
// ...
// Failed to download https://repo1.maven.org/maven2/org/apache/spark/spark-sql_3/4.1.1/spark-sql_3-4.1.1.pom
// Failed to download https://repo1.maven.org/maven2/sh/almond/almond-spark_3/0.14.0-RC8/almond-spark_3-0.14.0-RC8.pom
// ...
// Failed to download https://repo1.maven.org/maven2/sh/almond/almond-spark_3/0.14.0-RC8/almond-spark_3-0.14.0-RC8.pom.sha1
// ...
// Failed to download https://repo1.maven.org/maven2/org/apache/spark/spark-sql_3/4.1.1/spark-sql_3-4.1.1.pom.sha1
// ...
// Failed to download https://jitpack.io/org/apache/spark/spark-sql_3/4.1.1/spark-sql_3-4.1.1.pom
// ...
// Failed to download https://jitpack.io/org/apache/spark/spark-sql_3/4.1.1/spark-sql_3-4.1.1.pom.sha1
// Failed to download https://jitpack.io/sh/almond/almond-spark_3/0.14.0-RC8/almond-spark_3-0.14.0-RC8.pom
// ...
// Failed to download https://jitpack.io/sh/almond/almond-spark_3/0.14.0-RC8/almond-spark_3-0.14.0-RC8.pom.sha1
// Failed to resolve ivy dependencies:Error downloading sh.almond:almond-spark_3:0.14.0-RC8
// ...
