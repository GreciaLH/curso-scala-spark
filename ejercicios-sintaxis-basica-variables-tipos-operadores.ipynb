// %% [markdown]
// ## Ejercicio 1 — val y var

// %%
//val: describe el curso (no cambia durante la ejecución)
val nombreCurso = "Big Data con Scala"
val numeroDias = 28
val horasPorDia = 5.0

println(s"Curso: $nombreCurso")
println(s"Duración: $numeroDias días × $horasPorDia h/día = ${numeroDias * horasPorDia} horas")
// Out:
// Curso: Big Data con Scala
// Duración: 28 días × 5.0 h/día = 140.0 horas
// nombreCurso: String = "Big Data con Scala"
// numeroDias: Int = 28
// horasPorDia: Double = 5.0

// %%
// var: el contador de sesiones cambia a lo largo del programavar
var sesionesCompletadas = 0
println(s"Sesiones completadas al inicio: $sesionesCompletadas")

sesionesCompletadas = sesionesCompletadas + 1
println(s"Después de la Sesión 1: $sesionesCompletadas")

sesionesCompletadas += 1
println(s"Después de la Sesión 2: $sesionesCompletadas")
// Out:
// Sesiones completadas al inicio: 0
// Después de la Sesión 1: 1
// Después de la Sesión 2: 2
// sesionesCompletadas: Int = 2

// %%
// Descomenta la siguiente línea para ver el error de compilación:
numeroDias = 30
// error: reassignment to val
// Out:
// -- [E052] Type Error: cmd3.sc:1:22 ---------------------------------------------
// 1 |val res3 = numeroDias = 30
//   |           ^^^^^^^^^^^^^^^
//   |           Reassignment to val numeroDias
//   |
//   | longer explanation available when compiling with `-explain`
// Compilation Failed

// %% [markdown]
// ### Preguntas de reflexión
// 1. ¿Por qué `nombreCurso` y `numeroDias` son `val` y no `var`?
// nombreCurso y numeroDias son val porque representan datos que no deberían cambiar durante la ejecución
//
// 2. ¿Por qué `sesionesCompletadas` es `var`?
// sesionesCompletadas es var porque su valor sí cambia conforme avanzan las sesiones.
//
// 3. ¿Qué mensaje de error aparece si intentas reasignar un `val`?
// Al intentar reasignar un val aparece el error: reassignment to val.

// %% [markdown]
// ## Ejercicio 2 — Calculadora básica

// %%
val a: Double = 15.0
val b: Double = 4.0
val suma = a + b
val resta = a - b
val producto = a * b
val division = a / b
val modulo = a % b
println("=== Calculadora Scala ===")
println(f" $a%.1f + $b%.1f = $suma%.1f")
println(f" $a%.1f - $b%.1f = $resta%.1f")
println(f" $a%.1f × $b%.1f = $producto%.1f")
println(f" $a%.1f ÷ $b%.1f = $division%.4f")
println(f" $a%.1f %% $b%.1f = $modulo%.1f")
// Out:
// === Calculadora Scala ===
//  15,0 + 4,0 = 19,0
//  15,0 - 4,0 = 11,0
//  15,0 × 4,0 = 60,0
//  15,0 ÷ 4,0 = 3,7500
//  15,0 % 4,0 = 3,0
// a: Double = 15.0
// b: Double = 4.0
// suma: Double = 19.0
// resta: Double = 11.0
// producto: Double = 60.0
// division: Double = 3.75
// modulo: Double = 3.0

// %%
// División entera con Int
val a: Double = 15.0
val b: Double = 4.0

val x: Int = 15
val y: Int = 4

println(s"División entera: $x / $y = ${x / y}")
println(s"Resto: $x % $y = ${x % y}")

// Comparaciones
println(s"\n¿$a > $b? ${a > b}")
println(s"¿$a == $b? ${a == b}")
println(s"¿$a != $b? ${a != b}")
// Out:
// División entera: 15 / 4 = 3
// Resto: 15 % 4 = 3
//
// ¿15.0 > 4.0? true
// ¿15.0 == 4.0? false
// ¿15.0 != 4.0? true
// a: Double = 15.0
// b: Double = 4.0
// x: Int = 15
// y: Int = 4

// %%
val pesoKg = 75.0
val alturaMts = 1.78
val imc = pesoKg / (alturaMts * alturaMts)
val categoria =
    if (imc < 18.5) "Bajo peso"
    else if (imc < 25.0) "Normal"
    else if (imc < 30.0) "Sobrepeso"
    else "Obesidad"

println(f"IMC: $imc%.2f → $categoria")
// Out:
// IMC: 23,67 → Normal
// pesoKg: Double = 75.0
// alturaMts: Double = 1.78
// imc: Double = 23.671253629592222
// categoria: String = "Normal"

// %% [markdown]
// ## Ejercicio 3 — Interpolación de strings

// %%
val nombre = "Carlos García"
val edad = 32
val nota = 8.756
val aprobado = nota >= 5.0
val rutaInformes = raw"C:\Informes\Alumnos\2024"

// Interpolador s
println(s"Alumno: $nombre")
println(s"Edad: $edad años")
println(s"¿Ha aprobado? $aprobado")
println(s"Años hasta jubilación (65): ${65 - edad}")
// Out:
// Alumno: Carlos García
// Edad: 32 años
// ¿Ha aprobado? true
// Años hasta jubilación (65): 33
// nombre: String = "Carlos García"
// edad: Int = 32
// nota: Double = 8.756
// aprobado: Boolean = true
// rutaInformes: String = "C:\\Informes\\Alumnos\\2024"

// %%
// Interpolador f: formato decimal
println(f"Nota final: $nota%.2f")
println(f"Nota sobre 10: $nota%05.2f")

// Interpolador raw: ruta Windows sin problemas con \
println(s"\nRuta de informes: $rutaInformes")
// Out:
// Nota final: 8,76
// Nota sobre 10: 08,76
//
// Ruta de informes: C:\Informes\Alumnos\2024

// %% [markdown]
// # 💻 Ejercicios propuestos:

// %% [markdown]
// ## Ejercicio P1 — Ficha personal
// Declara las siguientes variables con el tipo adecuado e imprime una ficha con interpolador
// s:
// * Tu nombre (texto)
// * Tu edad (entero)
// * Tu altura en metros (decimal)
// * Si estás trabajando actualmente (booleano)

// %%
val nombre = "Laura Martínez"
val edad = 35
val altura = 1.68
val trabajando = true

println("=== Ficha Personal ===")
println(s"Nombre: $nombre")
println(s"Edad: $edad años")
println(f"Altura: $altura%.2f m")
println(s"Trabajando: $trabajando")
// Out:
// === Ficha Personal ===
// Nombre: Laura Martínez
// Edad: 35 años
// Altura: 1,68 m
// Trabajando: true
// nombre: String = "Laura Martínez"
// edad: Int = 35
// altura: Double = 1.68
// trabajando: Boolean = true

// %% [markdown]
// - `nombre`: **val**. En este ejercicio representa un dato fijo de la persona y no necesitamos modificarlo durante la ejecución.
// - `edad`: **var** (podría ser `val` si solo mostramos la ficha una vez). La edad cambia con el tiempo, por eso puede modelarse como variable mutable.
// - `altura`: **val** (o `var` según el contexto). Para una ficha simple puede quedar fija; sería `var` si quisiéramos actualizar mediciones.
// - `trabajando`: **var**. El estado laboral puede cambiar (`true`/`false`) según la situación de la persona.
//
// En resumen: en este ejercicio usé principalmente **val** para datos que no se modifican en la ejecución inmediata, y **var** solo cuando el dato puede cambiar en el tiempo o por requisitos del programa.

// %% [markdown]
// ## Ejercicio P2 — Conversor de minutos
// Declara una variable
// minutosTotales
// con el valor
// 137. Calcula y muestra cuántas horas y minutos son usandodivisión entera y el operador módulo %

// %%
val minutosTotales = 137
val horas = minutosTotales / 60
val minutos = minutosTotales % 60

println("=== Conversor de Minutos ===")
println(s"Minutos totales: $minutosTotales")
println(s"Equivalente a: $horas horas y $minutos minutos")
println(s"Verificación: ${horas * 60 + minutos} minutos")
// Out:
// === Conversor de Minutos ===
// Minutos totales: 137
// Equivalente a: 2 horas y 17 minutos
// Verificación: 137 minutos
// minutosTotales: Int = 137
// horas: Int = 2
// minutos: Int = 17

// %% [markdown]
// ## Ejercicio P3 — Comparador de precios
// Declara dos precios: precioA = 49.99 y precioB = 67.50. Usando operadores de comparación, imprime:

// %%
val precioA = 49.99
val precioB = 67.50
val diferencia = precioB - precioA

println(s"¿precioA es menor que precioB? ${precioA < precioB}")
println(s"¿Son iguales? ${precioA == precioB}")
println(s"¿precioA es mayor o igual? ${precioA >= precioB}")
println(f"La diferencia es: $diferencia%.2f €")
// Out:
// ¿precioA es menor que precioB? true
// ¿Son iguales? false
// ¿precioA es mayor o igual? false
// La diferencia es: 17,51 €
// precioA: Double = 49.99
// precioB: Double = 67.5
// diferencia: Double = 17.509999999999998

// %% [markdown]
// ## Ejercicio P4 — Etiqueta de producto
// Declara estas variables:
// - producto = "Teclado mecánico"
// - precio = 89.99
// - unidades = 3
// - enStock = true
// Construye e imprime la siguiente etiqueta usando únicamente el interpolador f

// %%
val producto = "Teclado mecánico"
val precio = 89.99
val unidades = 3
val enStock = true
val subtotal = precio * unidades

println(f"Producto: $producto")
println(f"Precio: $precio%.2f €")
println(f"Unidades: $unidades")
println(f"Subtotal: $subtotal%.2f €")
println(f"En stock: $enStock")
// Out:
// Producto: Teclado mecánico
// Precio: 89,99 €
// Unidades: 3
// Subtotal: 269,97 €
// En stock: true
// producto: String = "Teclado mecánico"
// precio: Double = 89.99
// unidades: Int = 3
// enStock: Boolean = true
// subtotal: Double = 269.96999999999997

// %% [markdown]
// ## Ejercicio P5 — Ruta de fichero
// Declara una variable carpeta con el valor "Documentos" y una variable fichero con el valor "informe_2024.csv".
// Construye e imprime la ruta completa de dos formas:

// %% [markdown]
// Salida esperada:
// Ruta con s: C:\Usuarios\Alumno\Documentos\informe_2024.csv
// Ruta con raw: C:\Usuarios\Alumno\Documentos\informe_2024.csv
//
// 💡 Con el interpoladors necesitarás escribir \\ para obtener \ . Con raw no.

// %%
val carpeta = "Documentos"
val fichero = "informe_2024.csv"

val rutaConS = s"C:\\Usuarios\\Alumno\\$carpeta\\$fichero"
val rutaConRaw = raw"C:\Usuarios\Alumno\$carpeta\$fichero"

println(s"Ruta con s: $rutaConS")
println(s"Ruta con raw: $rutaConRaw")
// Out:
// Ruta con s: C:\Usuarios\Alumno\Documentos\informe_2024.csv
// Ruta con raw: C:\Usuarios\Alumno\Documentos\informe_2024.csv
// carpeta: String = "Documentos"
// fichero: String = "informe_2024.csv"
// rutaConS: String = "C:\\Usuarios\\Alumno\\Documentos\\informe_2024.csv"
// rutaConRaw: String = "C:\\Usuarios\\Alumno\\Documentos\\informe_2024.csv"

// %% [markdown]
// ## Ejercicio P6 — Detector de tipo con getClass
// Scala permite consultar el tipo real de una variable en tiempo de ejecución con .getClass.getSimpleName. Declara seisvariables sin especificar su tipo, una por cada tipo primitivo de la sesión (Int, Long, Double, Float, Boolean, Char), y muestra el nombre de tipo que infiere Scala para cada una.

// %%
val entero = 42
val largo = 1000000000L
val doble = 3.14
val flotante = 3.14f
val booleano = true
val caracter = 'S'

println(s"$entero → ${entero.getClass.getSimpleName}")
println(s"${largo}L → ${largo.getClass.getSimpleName}")
println(s"$doble → ${doble.getClass.getSimpleName}")
println(s"${flotante}f → ${flotante.getClass.getSimpleName}")
println(s"$booleano → ${booleano.getClass.getSimpleName}")
println(s"'$caracter' → ${caracter.getClass.getSimpleName}")
// Out:
// 42 → int
// 1000000000L → long
// 3.14 → double
// 3.14f → float
// true → boolean
// 'S' → char
// entero: Int = 42
// largo: Long = 1000000000L
// doble: Double = 3.14
// flotante: Float = 3.14F
// booleano: Boolean = true
// caracter: Char = 'S'

// %% [markdown]
// ## Ejercicio P7 — Ticket de compra con IVA desglosado
// Declara tres productos con su precio base (sin IVA). El IVA general es del 21%. Calcula e imprime el ticket con elprecio base, el importe del IVA y el precio final de cada producto, más los totales. Usa el interpolador f para todoel formato.

// %%
val producto1 = "Monitor 4K"
val producto2 = "Teclado"
val producto3 = "Ratón"

val base1 = 299.99
val base2 = 49.99
val base3 = 29.99

println(f"========================================")
println(f" TICKET DE COMPRA")
println(f"========================================")
println(f"${"Producto"}%-14s ${"Base"}%8s ${"IVA"}%8s ${"Total"}%10s")
println(f"----------------------------------------")
println(f"$producto1%-14s $base1%8.2f ${base1 * 0.21}%8.2f ${base1 * 1.21}%9.2f €")
println(f"$producto2%-14s $base2%8.2f ${base2 * 0.21}%8.2f ${base2 * 1.21}%9.2f €")
println(f"$producto3%-14s $base3%8.2f ${base3 * 0.21}%8.2f ${base3 * 1.21}%9.2f €")
println(f"----------------------------------------")
println(f"${"TOTAL"}%-14s ${base1 + base2 + base3}%8.2f ${(base1 + base2 + base3) * 0.21}%8.2f ${(base1 + base2 + base3) * 1.21}%9.2f €")
println(f"========================================")
// Out:
// ...
//  TICKET DE COMPRA
// ...
// Producto           Base      IVA      Total
// ----------------------------------------
// Monitor 4K       299,99    63,00    362,99 €
// Teclado           49,99    10,50     60,49 €
// Ratón             29,99     6,30     36,29 €
// ----------------------------------------
// TOTAL            379,97    79,79    459,76 €
// ...
// producto1: String = "Monitor 4K"
// producto2: String = "Teclado"
// producto3: String = "Ratón"
// base1: Double = 299.99
// base2: Double = 49.99
// base3: Double = 29.99

// %% [markdown]
// ## Ejercicio P8 — Análisis de una nota
// Declara val nota: Double = 6.85. A partir de solo esa variable, calcula e imprime todo lo siguiente usandoúnicamente operadores y los tres interpoladores (s, f, raw):

// %%
val nota: Double = 6.85

val aprobado = nota >= 5.0
val notableOMas = nota >= 7.0
val sobre100 = nota * 10
val deficitA10 = 10 - nota
val nombreInforme = s"informe_nota_${f"$nota%.2f"}.txt"
val rutaInforme = raw"C:\Notas\$nombreInforme"

println(s"Nota: $nota")
println(f"Nota redondeada: $nota%.1f")
println(s"¿Aprobado? $aprobado")
println(s"¿Notable o más? $notableOMas")
println(s"Sobre 100: $sobre100")
println(f"Déficit a 10: $deficitA10%.2f")
println(s"Informe guardado en: $rutaInforme")
// Out:
// Nota: 6.85
// Nota redondeada: 6,9
// ¿Aprobado? true
// ¿Notable o más? false
// Sobre 100: 68.5
// Déficit a 10: 3,15
// Informe guardado en: C:\Notas\informe_nota_6,85.txt
// nota: Double = 6.85
// aprobado: Boolean = true
// notableOMas: Boolean = false
// sobre100: Double = 68.5
// deficitA10: Double = 3.1500000000000004
// nombreInforme: String = "informe_nota_6,85.txt"
// rutaInforme: String = "C:\\Notas\\informe_nota_6,85.txt"

// %% [markdown]
// ## Ejercicio P9 — Validador de credenciales
//
// Declara las siguientes variables:
// val usuario = "admin"
// val contrasena = "Scala2024"
// val intentos: Int = 3
// val bloqueado = intentos >= 3

// %%
val usuario = "admin"
val contrasena = "Scala2024"
val intentos: Int = 3
val bloqueado = intentos >= 3

val usuarioCorrecto = usuario == "admin"
val contrasenaCorrecta = contrasena == "Scala2024"
val puedeAcceder = usuarioCorrecto && contrasenaCorrecta && !bloqueado
val necesitaResetearClave = bloqueado || !contrasenaCorrecta

println(s"¿Usuario correcto? $usuarioCorrecto")
println(s"¿Contraseña correcta? $contrasenaCorrecta")
println(s"¿Cuenta bloqueada? $bloqueado")
println(s"¿Puede acceder? $puedeAcceder")
println(s"¿Necesita resetear clave? $necesitaResetearClave")
// Out:
// ¿Usuario correcto? true
// ¿Contraseña correcta? true
// ¿Cuenta bloqueada? true
// ¿Puede acceder? false
// ¿Necesita resetear clave? true
// usuario: String = "admin"
// contrasena: String = "Scala2024"
// intentos: Int = 3
// bloqueado: Boolean = true
// usuarioCorrecto: Boolean = true
// contrasenaCorrecta: Boolean = true
// puedeAcceder: Boolean = false
// necesitaResetearClave: Boolean = true

// %% [markdown]
// ## Ejercicio P10 — Conversor de unidades múltiple
// Declara val distanciaKm: Double = 142.5. A partir desolo esa variable, calcula la equivalencia en las cuatro unidadessiguientes y muestra la tabla con el interpolador
// f:
// Metros: 1 km = 1.000 m
// Millas: 1 km = 0.621371 millas
// Pies: 1 km = 3.280,84 pies
// Pulgadas: 1 km = 39.370,1 pulgadas

// %%
val distanciaKm: Double = 142.5

val kmAMetros = 1000.0
val kmAMillas = 0.621371
val kmAPies = 3280.84
val kmAPulgadas = 39370.1

val enMetros = distanciaKm * kmAMetros
val enMillas = distanciaKm * kmAMillas
val enPies = distanciaKm * kmAPies
val enPulgadas = distanciaKm * kmAPulgadas

println(f"=== Conversor de distancia ===")
println(f"Distancia original: $distanciaKm%.2f km")
println(f"En metros:   $enMetros%12.2f m")
println(f"En millas:   $enMillas%12.2f millas")
println(f"En pies:     $enPies%12.2f pies")
println(f"En pulgadas: $enPulgadas%12.2f pulgadas")
// Out:
// === Conversor de distancia ===
// Distancia original: 142,50 km
// En metros:      142500,00 m
// En millas:          88,55 millas
// En pies:        467519,70 pies
// En pulgadas:   5610239,25 pulgadas
// distanciaKm: Double = 142.5
// kmAMetros: Double = 1000.0
// kmAMillas: Double = 0.621371
// kmAPies: Double = 3280.84
// kmAPulgadas: Double = 39370.1
// enMetros: Double = 142500.0
// enMillas: Double = 88.5453675
// enPies: Double = 467519.7
// enPulgadas: Double = 5610239.25
